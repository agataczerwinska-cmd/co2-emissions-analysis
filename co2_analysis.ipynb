# %% [markdown]
# # Exploratory analysis of global CO2 emissions using World Bank ESG data

# %%
import pandas as pd
esg = pd.read_csv("ESGData.csv")
esg.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 2  Adjusted savings: natural resources depletion ...  NY.ADJ.DRES.GN.ZS   NaN
# 3  Adjusted savings: net forest depletion (% of GNI)  NY.ADJ.DFOR.GN.ZS   NaN
# 4                 Agricultural land (% of land area)     AG.LND.AGRI.ZS   NaN
#
#         1961       1962       1963       1964       1965  ...       2013  \
# 0        NaN        NaN        NaN        NaN        NaN  ...  83.533457
# 1        NaN        NaN        NaN        NaN        NaN  ...  88.129881
# 2        NaN        NaN        NaN        NaN        NaN  ...  11.641062
# ...

# %%
esg[esg["Indicator Name"].str.contains("CO2 emissions", case=False, na=False)]
# Out:
#                          Country Name Country Code  \
# 10                         Arab World          ARB
# 77             Caribbean small states          CSS
# 144    Central Europe and the Baltics          CEB
# 211        Early-demographic dividend          EAR
# 278               East Asia & Pacific          EAS
# ...                               ...          ...
# 15688                   Venezuela, RB          VEN
# 15755                         Vietnam          VNM
# 15822                     Yemen, Rep.          YEM
# 15889                          Zambia          ZMB
# 15956                        Zimbabwe          ZWE
#
#                                Indicator Name  Indicator Code      1960  \
# 10     CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.607448
# 77     CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  1.401336
# 144    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  5.104206
# ...

# %%
co2 = esg[esg["Indicator Name"] == "CO2 emissions (metric tons per capita)"]
co2.head()
# Out:
#                        Country Name Country Code  \
# 10                       Arab World          ARB
# 77           Caribbean small states          CSS
# 144  Central Europe and the Baltics          CEB
# 211      Early-demographic dividend          EAR
# 278             East Asia & Pacific          EAS
#
#                              Indicator Name  Indicator Code      1960  \
# 10   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.607448
# 77   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  1.401336
# 144  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  5.104206
# 211  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.603548
# 278  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  1.167559
#
#          1961      1962      1963      1964      1965  ...      2013  \
# 10   0.660638  0.724944  0.850567  0.969476  1.135271  ...  4.801390
# 77   2.059977  2.703740  1.350237  2.362951  2.601917  ...  9.160637
# ...

# %%
co2_countries = co2[~co2["Country Name"].isin([
    "Arab World", "Caribbean small states", "Central Europe and the Baltics",
    "Early-demographic dividend", "East Asia & Pacific", "East Asia & Pacific (excluding high income)",
    "East Asia & Pacific (IDA & IBRD)", "Euro area", "Europe & Central Asia",
    "Europe & Central Asia (excluding high income)", "Europe & Central Asia (IDA & IBRD)",
    "European Union", "Fragile and conflict affected situations", "Heavily indebted poor countries (HIPC)",
    "High income", "Low & middle income", "Low income", "Lower middle income",
    "Middle income", "OECD members", "South Asia", "Sub-Saharan Africa",
    "Sub-Saharan Africa (excluding high income)", "Upper middle income", "World"
])]

# %%
co2_countries = co2_countries[co2_countries["Country Name"] != "North America"]

# %%
co2_countries[["Country Name", "2014"]].sort_values("2014", ascending=False).head(15)
# Out:
#                Country Name       2014
# 12472                 Qatar  43.523293
# 14817   Trinidad and Tobago  33.961031
# 15286  United Arab Emirates  24.543043
# 9189                 Kuwait  23.942684
# 3896                Bahrain  23.477363
# 4700      Brunei Darussalam  22.094944
# 12941          Saudi Arabia  19.440666
# 9859             Luxembourg  17.368713
# 15420         United States  16.416576
# 3628              Australia  15.391109
# 5169                 Canada  15.255472
# 11802                  Oman  15.201543
# 8854             Kazakhstan  14.367836
# 6777                Estonia  13.825051
# 11936                 Palau  12.690741

# %%
import matplotlib.pyplot as plt

top15 = co2_countries[["Country Name", "2014"]].sort_values("2014", ascending=False).head(15)

plt.figure(figsize=(10,6))
plt.barh(top15["Country Name"], top15["2014"])
plt.xlabel("CO2 emissions (metric tons per capita)")
plt.title("Top 15 CO2 emitters per capita, 2014")
plt.gca().invert_yaxis()  # so #1 is at the top
plt.show()

# %%
chile = co2_countries[co2_countries["Country Name"] == "Chile"]
chile
# Out:
#      Country Name Country Code                          Indicator Name  \
# 5370        Chile          CHL  CO2 emissions (metric tons per capita)
#
#       Indicator Code      1960      1961      1962      1963      1964  \
# 5370  EN.ATM.CO2E.PC  1.658786  1.743013  1.973032  2.006374  1.986497
#
#           1965  ...      2013      2014      2015      2016  2017  2018  2019  \
# 5370  1.976348  ...  4.736431  4.454138  4.632586  4.713172   NaN   NaN   NaN
#
#       2020  2050  Unnamed: 66
# 5370   NaN   NaN          NaN
#
# [1 rows x 67 columns]

# %%
year_columns = [str(y) for y in range(1990, 2015)]  # pick a reasonable range
chile_long = chile.melt(id_vars=["Country Name"], value_vars=year_columns,
                          var_name="Year", value_name="CO2_per_capita")
chile_long
# Out:
#    Country Name  Year  CO2_per_capita
# 0         Chile  1990        2.509653
# 1         Chile  1991        2.321076
# 2         Chile  1992        2.367010
# 3         Chile  1993        2.483158
# 4         Chile  1994        2.689742
# 5         Chile  1995        2.902824
# 6         Chile  1996        3.324776
# 7         Chile  1997        3.814010
# 8         Chile  1998        3.848484
# 9         Chile  1999        4.056172
# 10        Chile  2000        3.833507
# 11        Chile  2001        3.437728
# 12        Chile  2002        3.517039
# 13        Chile  2003        3.508135
# 14        Chile  2004        3.732493
# 15        Chile  2005        3.820018
# 16        Chile  2006        3.963081
# 17        Chile  2007        4.333797
# 18        Chile  2008        4.300340
# 19        Chile  2009        3.956216
# 20        Chile  2010        4.234476
# 21        Chile  2011        4.598226
# 22        Chile  2012        4.653625
# 23        Chile  2013        4.736431
# ...

# %%
plt.figure(figsize=(10,5))
plt.plot(chile_long["Year"], chile_long["CO2_per_capita"], marker="o")
plt.xticks(chile_long["Year"][::5], rotation=45)  # only show every 5th year
plt.title("Chile: CO2 emissions per capita over time")
plt.ylabel("Metric tons per capita")
plt.tight_layout()
plt.savefig("chile_co2_trend.png", bbox_inches="tight", dpi=150)
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
